# %%
import pandas as pd

# %%
print("Welcome to Taj Hotel")
print("Please choose the menu catagories: \n ")
while(True):
   print("Please Press 1 for -> Breakfast \nPlease Press 2 for -> Lunch \nPlease Press 3 for -> Dinner \nPlease Press 4 for -> Drink \n")
   num=int(input("Enter your choose:"))
   if num <= 4 and num > 0:     
       match(num):
           case 1 :
                   print("You choose Breakfast")
                   print("For breakfast we have a varity of dishes:\n")
                   brk={"Sr.no":[0,1,2,3,4,5,6],
                        "Breakfast_items":["Idli","Nut butter","Dosa","Upma","Poha","Paratha","Dhokla"],
                        "Price":[250,300,450,200,150,100,500] }
                   dat_1=pd.DataFrame(brk ,index=["->","->","->","->","->","->","->"])
                   print( dat_1)
                   item=int(input("\nEnter no. of dishes you want to order:\n"))
                   thk="\nThanks for choosing Taj Hotel"
                   match item:
                         case 1:
                               It_1=int(input("\nPlease choose Sr.no of dish:\n"))
                               Select_items=dat_1.iloc[It_1]
                             
                               total_sum = Select_items['Price'].sum()
                               print("Selected dish:\n", Select_items)
                             
                               Num=int(input("Enter the quantity of dish:\n"))
                               print("Total Price of selected dish:", total_sum * Num)
                               print(thk)
                               
                         case 2:
                               It_1, It_2,= map(int, input("\nPlease choose Sr.no of dishes:\n ").split())
                               Select_items=dat_1.iloc[[It_1, It_2]]
                             
                               total_sum = Select_items['Price'].sum()
                               print("Selected dishes:\n", Select_items)
                             
                               Num=int(input("Enter the quantity of dishes:\n"))
                               print("Total Price of selected dishes:", total_sum * Num)
                               print(thk)
                               
                         case 3:
                               It_1, It_2, It_3= map(int, input("\nPlease choose Sr.no of dishes:\n ").split())
                               Select_items=dat_1.iloc[[It_1, It_2, It_3]]
                             
                               total_sum = Select_items['Price'].sum()
                               print("Selected dishes:\n", Select_items)
                             
                               Num=int(input("Enter the quantity of dishes:\n"))
                               print("Total Price of selected dishes:", total_sum * Num)
                               print(thk)
                             
                         case 4:
                               It_1, It_2, It_3, It_4= map(int, input("\nPlease choose Sr.no of dishes:\n").split())
                               Select_items=dat_1.iloc[[It_1, It_2, It_3, It_4]]
                               
                               total_sum = Select_items['Price'].sum()
                               print("Selected dishes:\n", Select_items)
                             
                               Num=int(input("Enter the quantity of dishes:\n"))
                               print("Total Price of selected dishes:", total_sum * Num)
                               print(thk)
                             
                         case 5:
                               It_1, It_2, It_3, It_4, It_5= map(int, input("\nPlease choose Sr.no of dishes:\n").split())
                               Select_items=dat_1.iloc[[It_1, It_2, It_3, It_4, It_5]]
                             
                               total_sum = Select_items['Price'].sum()
                               print("Selected dishes:\n", Select_items)
                             
                               Num=int(input("Enter the quantity of dishes:\n"))
                               print("Total Price of selected dishes:", total_sum * Num)
                               print(thk)
                             
                         case 6:
                               It_1, It_2, It_3, It_4, It_5, It_6= map(int, input("\nPlease choose Sr.no of items:\n").split())
                               Select_items=dat_1.iloc[[It_1, It_2, It_3, It_4, It_5, It_6 ]]
                             
                               total_sum = Select_items['Price'].sum()
                               print("Selected Items:\n", Select_items)
                             
                               Num=int(input("Enter the quantity of dishes:\n"))
                               print("Total Price of selected dishes:", total_sum * Num)
                               print(thk)
                         case _:
                               Select_items=dat_1
                               total_sum = Select_items['Price'].sum()
                               print("Selected dishes:\n", Select_items)
                             
                               Num=int(input("Enter the quantity of dishes:\n"))
                               print("Total Price of selected dishes:", total_sum * Num)
                               print(thk)
                   
                   break
     
           case 2 :
                   print("You choose Lunch")
                   print("For Lunch we have a varity of dishes:\n")
                   Lch={"Sr.no":[0,1,2,3,4,5,6],
                        "Lunch items":["Sandwiches","Pizza","Rice paper rolls","Salads","Sushi rolls","Noodles with veggies ","Chole bhature"],
                        "Price":[270,350,450,100,150,420,510] }
                   dat_2=pd.DataFrame(Lch ,index=["->","->","->","->","->","->","->"])
                   print(dat_2)
                   item=int(input("\nEnter no. of dishes you want to order:\n"))
                   thk="\nThanks for choosing Taj Hotel"
                   match item:
                         case 1:
                               It_1=int(input("\nPlease choose Sr.no of dish:\n"))
                               Select_items=dat_2.iloc[It_1]
                             
                               total_sum = Select_items['Price'].sum()
                               print("Selected dish:\n", Select_items)
                             
                               Num=int(input("Enter the quantity of dish:\n"))
                               print("Total Price of selected dish:", total_sum * Num)
                               print(thk)
                               
                         case 2:
                               It_1, It_2,= map(int, input("\nPlease choose Sr.no of dishes:\n ").split())
                               Select_items=dat_2.iloc[[It_1, It_2]]
                             
                               total_sum = Select_items['Price'].sum()
                               print("Selected dishes:\n", Select_items)
                             
                               Num=int(input("Enter the quantity of dishes:\n"))
                               print("Total Price of selected dishes:", total_sum * Num)
                               print(thk)
                             
                         case 3:
                               It_1, It_2, It_3= map(int, input("\nPlease choose Sr.no of dishes:\n ").split())
                               Select_items=dat_2.iloc[[It_1, It_2, It_3]]
                             
                               total_sum = Select_items['Price'].sum()
                               print("Selected dishes:\n", Select_items)
                             
                               Num=int(input("Enter the quantity of dishes:\n"))
                               print("Total Price of selected dishes:", total_sum * Num)
                               print(thk)
                             
                         case 4:
                               It_1, It_2, It_3, It_4= map(int, input("\nPlease choose Sr.no of dishes:\n").split())
                               Select_items=dat_2.iloc[[It_1, It_2, It_3, It_4]]
                               
                               total_sum = Select_items['Price'].sum()
                               print("Selected dishes:\n", Select_items)
                             
                               Num=int(input("Enter the quantity of dishes:\n"))
                               print("Total Price of selected dishes:", total_sum * Num)
                               print(thk)
                             
                         case 5:
                               It_1, It_2, It_3, It_4, It_5= map(int, input("\nPlease choose Sr.no of dishes:\n").split())
                               Select_items=dat_2.iloc[[It_1, It_2, It_3, It_4, It_5]]
                             
                               total_sum = Select_items['Price'].sum()
                               print("Selected Items:\n", Select_items)
                             
                               Num=int(input("Enter the quantity of dishes:\n"))
                               print("Total Price of selected dishes:", total_sum * Num)
                               print(thk)
                             
                         case 6:
                               It_1, It_2, It_3, It_4, It_5, It_6= map(int, input("\nPlease choose Sr.no of dishes:\n").split())
                               Select_items=dat_2.iloc[[It_1, It_2, It_3, It_4, It_5, It_6 ]]
                             
                               total_sum = Select_items['Price'].sum()
                               print("Selected dishes:\n", Select_items)
                             
                               Num=int(input("Enter the quantity of dishes:\n"))
                               print("Total Price of selected dishes:", total_sum * Num)
                               print(thk)
                             
                         case _:
                               Select_items=dat_2
                               total_sum = Select_items['Price'].sum()
                               print("Selected dishes:\n", Select_items)
                             
                               Num=int(input("Enter the quantity of dishes:\n"))
                               print("Total Price of selected dishes:", total_sum * Num)
                               print(thk)
                   break
    
           case 3 :
                   print("You choose Dinner")
                   print("For Dinner we have a varity of dishes:\n")
                   din={"Sr.no":[0,1,2,3,4,5,6],
                        "Dinner items":["Aloo Gobi","Dal Makhani","Palak Paneer","Sambar","Saag Aloo","Methi Matar Malai","Gobhi Paratha"],
                        "Price":[350,400,450,250,150,700,500] }
                   dat_3=pd.DataFrame(din ,index=["->","->","->","->","->","->","->"])
                   print(dat_3)
                   item=int(input("\nEnter no. of dishes you want to order:\n"))
                   thk="\nThanks for choosing Taj Hotel"
                   match item:
                         case 1:
                               It_1=int(input("\nPlease choose Sr.no of dish:\n"))
                               Select_items=dat_3.iloc[It_1]
                             
                               total_sum = Select_items['Price'].sum()
                               print("Selected dish:\n", Select_items)
                             
                               Num=int(input("Enter the quantity of dish:\n"))
                               print("Total Price of selected dish:", total_sum * Num)
                               print(thk)
                               
                         case 2:
                               It_1, It_2,= map(int, input("\nPlease choose Sr.no of dishes:\n ").split())
                               Select_items=dat_3.iloc[[It_1, It_2]]
                             
                               total_sum = Select_items['Price'].sum()
                               print("Selected dishes:\n", Select_items)
                             
                               Num=int(input("Enter the quantity of dishes:\n"))
                               print("Total Price of selected dishes:", total_sum * Num)
                               print(thk)
                             
                         case 3:
                               It_1, It_2, It_3= map(int, input("\nPlease choose Sr.no of dishes:\n ").split())
                               Select_items=dat_3.iloc[[It_1, It_2, It_3]]
                             
                               total_sum = Select_items['Price'].sum()
                               print("Selected dishes:\n", Select_items)
                             
                               Num=int(input("Enter the quantity of dishes:\n"))
                               print("Total Price of selected dishes:", total_sum * Num)
                               print(thk)
                             
                         case 4:
                               It_1, It_2, It_3, It_4= map(int, input("\nPlease choose Sr.no of dishes:\n").split())
                               Select_items=dat_3.iloc[[It_1, It_2, It_3, It_4]]
                               
                               total_sum = Select_items['Price'].sum()
                               print("Selected dishes:\n", Select_items)
                             
                               Num=int(input("Enter the quantity of dishes:\n"))
                               print("Total Price of selected dishes:", total_sum * Num)
                               print(thk)
                             
                         case 5:
                               It_1, It_2, It_3, It_4, It_5= map(int, input("\nPlease choose Sr.no of dishes:\n").split())
                               Select_items=dat_3.iloc[[It_1, It_2, It_3, It_4, It_5]]
                             
                               total_sum = Select_items['Price'].sum()
                               print("Selected dishes\n", Select_items)
                             
                               Num=int(input("Enter the quantity of dishes:\n"))
                               print("Total Price of selected dishes:", total_sum * Num)
                               print(thk)
                             
                         case 6:
                               It_1, It_2, It_3, It_4, It_5, It_6= map(int, input("\nPlease choose Sr.no of dishes:\n").split())
                               Select_items=dat_3.iloc[[It_1, It_2, It_3, It_4, It_5, It_6 ]]
                             
                               total_sum = Select_items['Price'].sum()
                               print("Selected dishes:\n", Select_items)
                             
                               Num=int(input("Enter the quantity of dishes:\n"))
                               print("Total Price of selected dishes:", total_sum * Num)
                               print(thk)
                             
                         case _:
                               Select_items=dat_3
                               total_sum = Select_items['Price'].sum()
                               print("Selected dishes:\n", Select_items)
                             
                               Num=int(input("Enter the quantity of dishes:\n"))
                               print("Total Price of selected dishes:", total_sum * Num)
                               print(thk)
                   break
           case 4 :
                   print("You choose Drink")
                   print("For Drink we have a varity of drinks:\n")
                   drk={"Sr.no":[0,1,2,3,4,5,6],
                        "Drink items":["Water","Coffee","Orange Juice","Soda", "Milkshake","Paua","Coca Cola"],
                        "Price":[50,450,250,150,80,100,180] }
                   dat_4=pd.DataFrame(drk,index=["->","->","->","->","->","->","->"])
                   print(dat_4)
                   item=int(input("\nEnter no. of drinks you want to order:\n"))
                   thk="\nThanks for choosing Taj Hotel"
                   match item:
                         case 1:
                               It_1=int(input("\nPlease choose Sr.no of drink:\n"))
                               Select_items=dat_4.iloc[It_1]
                             
                               total_sum = Select_items['Price'].sum()
                               print("Selected drink:\n", Select_items)
                             
                               Num=int(input("Enter the quantity of drink:\n"))
                               print("Total Price of selected drink:", total_sum * Num)
                               print(thk)
                               
                         case 2:
                               It_1, It_2,= map(int, input("\nPlease choose Sr.no of drinks:\n ").split())
                               Select_items=dat_4.iloc[[It_1, It_2]]
                             
                               total_sum = Select_items['Price'].sum()
                               print("Selected drinks:\n", Select_items)
                             
                               Num=int(input("Enter the quantity of drinks:\n"))
                               print("Total Price of selected drinks:", total_sum * Num)
                               print(thk)
                             
                         case 3:
                               It_1, It_2, It_3= map(int, input("\nPlease choose Sr.no of drinks:\n ").split())
                               Select_items=dat_4.iloc[[It_1, It_2, It_3]]
                             
                               total_sum = Select_items['Price'].sum()
                               print("Selected drinks:\n", Select_items)
                             
                               Num=int(input("Enter the quantity of drinks:\n"))
                               print("Total Price of selected drinks:", total_sum * Num)
                               print(thk)
                             
                         case 4:
                               It_1, It_2, It_3, It_4= map(int, input("\nPlease choose Sr.no of drinks:\n").split())
                               Select_items=dat_4.iloc[[It_1, It_2, It_3, It_4]]
                               
                               total_sum = Select_items['Price'].sum()
                               print("Selected drinks:\n", Select_items)
                             
                               Num=int(input("Enter the quantity of drinks:\n"))
                               print("Total Price of selected drinks:", total_sum * Num)
                               print(thk)
                             
                         case 5:
                               It_1, It_2, It_3, It_4, It_5= map(int, input("\nPlease choose Sr.no of drinks:\n").split())
                               Select_items=dat_4.iloc[[It_1, It_2, It_3, It_4, It_5]]
                             
                               total_sum = Select_items['Price'].sum()
                               print("Selected drinks:\n", Select_items)
                             
                               Num=int(input("Enter the quantity of drinks:\n"))
                               print("Total Price of selected drinks:", total_sum * Num)
                               print(thk)
                             
                         case 6:
                               It_1, It_2, It_3, It_4, It_5, It_6= map(int, input("\nPlease choose Sr.no of drinks:\n").split())
                               Select_items=dat_4.iloc[[It_1, It_2, It_3, It_4, It_5, It_6 ]]
                             
                               total_sum = Select_items['Price'].sum()
                               print("Selected drinks:\n", Select_items)
                             
                               Num=int(input("Enter the quantity of drinks:\n"))
                               print("Total Price of selected drinks:", total_sum * Num)
                               print(thk)
                             
                         case _:
                               Select_items=dat_4
                               total_sum = Select_items['Price'].sum()
                               print("Selected drinks:\n", Select_items)
                             
                               Num=int(input("Enter the quantity of drinks:\n"))
                               print("Total Price of selected drinks:", total_sum * Num)
                               print(thk)
                             
                   break
   else:
        print("\nOOPS! wrong choise \nPlease choose correct option\n")
# Out:
# Welcome to Taj Hotel
# Please choose the menu catagories:
#
# Please Press 1 for -> Breakfast
# Please Press 2 for -> Lunch
# Please Press 3 for -> Dinner
# Please Press 4 for -> Drink
# Enter your choose: 4
# You choose Drink
# For Drink we have a varity of drinks:
#
#     Sr.no   Drink items  Price
# ->      0         Water     50
# ->      1        Coffee    450
# ->      2  Orange Juice    250
# ->      3          Soda    150
# ->      4     Milkshake     80
# ->      5          Paua    100
# ->      6     Coca Cola    180
# Enter no. of drinks you want to order:
#  3
#
# Please choose Sr.no of drinks:
#   0 4 5
# Selected drinks:
#      Sr.no Drink items  Price
# ->      0       Water     50
# ->      4   Milkshake     80
# ->      5        Paua    100
# Enter the quantity of drinks:
#  2
# Total Price of selected drinks: 460
#
# Thanks for choosing Taj Hotel
